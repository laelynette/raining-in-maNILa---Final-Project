# %% [markdown]
# # Raining in MaNILa - Metaheuristic Algorithm

# %% [markdown]
# #### Data Preprocessing

# %%
## Import necessary libraries
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_2018 = pd.read_csv(r'/content/drive/Shareddrives/DATASET raining in maNILa/kapagodpo.csv',
                 skipinitialspace=True)
df_2018.head()
# Out:
#    FlightDate  Month TimeOfDay                 Airline  Distance  \
# 0  2020-01-01      1  Midnight    Delta Air Lines Inc.    1535.0
# 1  2020-01-01      1  Midnight    Delta Air Lines Inc.     196.0
# 2  2020-01-01      1  Midnight    Delta Air Lines Inc.    1533.0
# 3  2020-01-01      1  Midnight    Delta Air Lines Inc.    1590.0
# 4  2020-01-01      1  Midnight  Southwest Airlines Co.     277.0
#
#    ESTDepTotalMinutes    Route  AvgDelayPerRoute  DepDelayAvgPerMonth  \
# 0               240.0  LAX-MSP          6.448685             8.521821
# 1               300.0  FSD-MSP          6.249456             8.521821
# 2               300.0  FAI-SEA          2.816303             8.521821
# 3               309.0  SLC-ATL          8.642204             8.521821
# 4               315.0  HRL-HOU          6.403361             8.521821
#
#    Holiday  DepDelay
# 0     True       0.0
# 1     True       0.0
# 2     True       0.0
# 3     True       3.0
# 4     True       1.0

# %%
df_2018.shape
# Out:
# (3200090, 11)

# %%
df_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3200090 entries, 0 to 3200089
# Data columns (total 11 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   FlightDate           object
#  1   Month                int64
#  2   TimeOfDay            object
#  3   Airline              object
#  4   Distance             float64
#  5   ESTDepTotalMinutes   float64
#  6   Route                object
#  7   AvgDelayPerRoute     float64
#  8   DepDelayAvgPerMonth  float64
#  9   Holiday              bool
#  10  DepDelay             float64
# dtypes: bool(1), float64(5), int64(1), object(4)
# memory usage: 247.2+ MB

# %%
## Convert distance from miles to kilometer
def to_km(val):
    return val*1.609344

# %% [markdown]
# #### Try pseudo routes

# %%
df_2018['Route'].value_counts()
# Out:
# Route
# MCO-ATL    10863
# ATL-MCO    10647
# TPA-ATL     9352
# ATL-TPA     9270
# FLL-ATL     8870
#            ...
# LGA-CHS        1
# JFK-RIC        1
# DTW-GSO        1
# IAD-LAS        1
# CHS-LGA        1
# Name: count, Length: 2676, dtype: int64

# %%
routes = df_2018['Route'].values
routes
# Out:
# array(['LAX-MSP', 'FSD-MSP', 'FAI-SEA', ..., 'SFO-ATL', 'SEA-ATL',
#        'LAX-JFK'], dtype=object)

# %%
def separate_strings_with_dash(string_list):
    # Split each string in the list by "-" and flatten the result
    separated_strings = [substring for string in string_list for substring in string.split("-")]
    return separated_strings

# %%
routes = separate_strings_with_dash(routes)
routes
# Out:
# ['LAX',
#  'MSP',
#  'FSD',
#  'MSP',
#  'FAI',
#  'SEA',
#  'SLC',
#  'ATL',
#  'HRL',
#  'HOU',
#  'MSP',
#  'ATL',
#  'DEN',
#  'PHX',
#  'VPS',
#  'ATL',
#  'AUS',
#  'STL',
#  'HOU',
#  'FLL',
#  'BHM',
#  'HOU',
#  'TUL',
#  'HOU',
#  'MSY',
#  'ATL',
#  'MCI',
#  'MCO',
#  'MKE',
#  'DEN',
#  'BHM',
#  'ATL',
#  'PIT',
#  'MCO',
#  'OAK',
#  'PHX',
#  'BDL',
#  'DTW',
#  'MKE',
#  'BNA',
#  'CMH',
#  'MCO',
#  'ABQ',
#  'HOU',
#  'SAT',
#  'STL',
#  'DEN',
#  'BNA',
#  'MSP',
#  'MDW',
#  'HOU',
#  'STL',
#  'STL',
#  'HOU',
#  'CHS',
#  'MDW',
#  'MCI',
#  'ATL',
#  'ATW',
#  'ATL',
#  'OMA',
#  'ATL',
#  'LAX',
#  'AUS',
#  'SAT',
#  'DEN',
#  'PHX',
#  'MDW',
#  'BNA',
#  'MCO',
#  'AUS',
#  'HOU',
#  'SEA',
#  'PHX',
#  'CMH',
#  'ATL',
#  'STL',
#  'ATL',
#  'MSY',
#  'ATL',
#  'HOU',
#  'ATL',
#  'PHL',
#  'BNA',
#  'CLE',
#  'ATL',
#  'MCI',
#  'DAL',
#  'PNS',
#  'ATL',
#  'BOS',
#  'DTW',
#  'DTW',
#  'MDW',
#  'PDX',
#  'MDW',
#  'AUS',
#  'MDW',
#  'RNO',
#  'LAX',
#  'HOU',
#  'TPA',
#  'DTW',
#  'ATL',
#  'CLE',
#  'BNA',
#  'BOS',
#  'ATL',
#  'SLC',
#  'DTW',
#  'STL',
#  'BWI',
#  'ICT',
#  'ATL',
#  'STL',
#  'FLL',
#  'CID',
#  'ATL',
#  'AUS',
#  'LAS',
#  'EWR',
#  'DTW',
#  'HOU',
#  'MDW',
#  'LIT',
#  'ATL',
#  'ORD',
#  'ATL',
#  'GEG',
#  'OAK',
#  'BNA',
#  'LGA',
#  'CLT',
#  'BWI',
#  'MCO',
#  'SLC',
#  'MCI',
#  'PHX',
#  'ALB',
#  'BWI',
#  'PWM',
#  'ATL',
#  'MAF',
#  'HOU',
#  'MKE',
#  'ATL',
#  'LAS',
#  'ONT',
#  'GEG',
#  'PHX',
#  'OKC',
#  'HOU',
#  'FLL',
#  'ATL',
#  'ALB',
#  'ATL',
#  'HOU',
#  'MSY',
#  'MLB',
#  'ATL',
#  'SFO',
#  'DEN',
#  'RDU',
#  'DTW',
#  'SRQ',
#  'ATL',
#  'CLE',
#  'BWI',
#  'MEM',
#  'HOU',
#  'CMH',
#  'MDW',
#  'BUF',
#  'ATL',
#  'ROA',
#  'ATL',
#  'AUS',
#  'ATL',
#  'BOS',
#  'DEN',
#  'ABQ',
#  'ATL',
#  'LAS',
#  'ATL',
#  'MCI',
#  'LGA',
#  'PHX',
#  'ATL',
#  'DFW',
#  'MSP',
#  'DEN',
#  'IND',
#  'PDX',
#  'SLC',
#  'BZN',
#  'SLC',
#  'ATL',
#  'LGA',
#  'FAY',
#  'ATL',
#  'IND',
#  'ATL',
#  'JAX',
#  'ATL',
#  'PHX',
#  'STL',
#  'DEN',
#  'PHL',
#  'ECP',
#  'ATL',
#  'PHX',
#  'ATL',
#  'IAH',
#  'ATL',
#  'RDU',
#  'ATL',
#  'RDU',
#  'ATL',
#  'HOU',
#  'ATL',
#  'MCO',
#  'ATL',
#  'TUL',
#  'ATL',
#  'OAK',
#  'SLC',
#  'MCI',
#  'MSP',
#  'SAT',
#  'ATL',
#  'BDL',
#  'ATL',
#  'DTW',
#  'PHX',
#  'PHL',
#  'MSP',
#  'SLC',
#  'DEN',
#  'ELP',
#  'ATL',
#  'GEG',
#  'SLC',
#  'PVD',
#  'ATL',
#  'SFO',
#  'ATL',
#  'LGA',
#  'ATL',
#  'DCA',
#  'MSP',
#  'MEM',
#  'ATL',
#  'FLL',
#  'LAS',
#  'PDX',
#  'MSP',
#  'FLL',
#  'ATL',
#  'BWI',
#  'ATL',
#  'BNA',
#  'FLL',
#  'LBB',
#  'DAL',
#  'BWI',
#  'DTW',
#  'LGA',
#  'MDW',
#  'LGA',
#  'DTW',
#  'LGA',
#  'BNA',
#  'DFW',
#  'ATL',
#  'LGA',
#  'MSP',
#  'TPA',
#  'ATL',
#  'CLT',
#  'ATL',
#  'LAS',
#  'SLC',
#  'AUS',
#  'SEA',
#  'GPT',
#  'ATL',
#  'DCA',
#  'DTW',
#  'SFO',
#  'DAL',
#  'TUS',
#  'ATL',
#  'MDW',
#  'FLL',
#  'RIC',
#  'ATL',
#  'CHO',
#  'ATL',
#  'GRR',
#  'ATL',
#  'DCA',
#  'ATL',
#  'DAL',
#  'TPA',
#  'TPA',
#  'DEN',
#  'ONT',
#  'SJC',
#  'DCA',
#  'BNA',
#  'LAX',
#  'SLC',
#  'RSW',
#  'ATL',
#  'MSO',
#  'SLC',
#  'MEM',
#  'MDW',
#  'DCA',
#  'JFK',
#  'AVP',
#  'ATL',
#  'SYR',
#  'ATL',
#  'MDW',
#  'MCO',
#  'MDW',
#  'ATL',
#  'MDW',
#  'RSW',
#  'DAL',
#  'SAN',
#  'ROC',
#  'ATL',
#  'MYR',
#  'ATL',
#  'DAL',
#  'PHX',
#  'PBI',
#  'LGA',
#  'SDF',
#  'ATL',
#  'RNO',
#  'SJC',
#  'ANC',
#  'SEA',
#  'RSW',
#  'ATL',
#  'DAY',
#  'ATL',
#  'DEN',
#  'SAN',
#  'DAL',
#  'MCI',
#  'MKE',
#  'LAS',
#  'MDT',
#  'ATL',
#  'CRW',
#  'ATL',
#  'DAL',
#  'LGA',
#  'JFK',
#  'ATL',
#  'MSP',
#  'BNA',
#  'MKE',
#  'LGA',
#  'OMA',
#  'MDW',
#  'SMF',
#  'LAX',
#  'BDL',
#  'BWI',
#  'PIT',
#  'ATL',
#  'DEN',
#  'MDW',
#  'RSW',
#  'DTW',
#  'DAL',
#  'MCO',
#  'DCA',
#  'DAL',
#  'DAL',
#  'FLL',
#  'BNA',
#  'MCI',
#  'SEA',
#  'DEN',
#  'LAS',
#  'JFK',
#  'HOU',
#  'DEN',
#  'MDW',
#  'LGA',
#  'TUS',
#  'LAX',
#  'SAT',
#  'DAL',
#  'AUS',
#  'BWI',
#  'PDX',
#  'PHX',
#  'MCO',
#  'LAX',
#  'PDX',
#  'LAX',
#  'LAS',
#  'BWI',
#  'OAK',
#  'DEN',
#  'PHL',
#  'HOU',
#  'OKC',
#  'STL',
#  'FSD',
#  'ATL',
#  'MSP',
#  'STL',
#  'DTW',
#  'DEN',
#  'BDL',
#  'MDW',
#  'BOS',
#  'JFK',
#  'SMF',
#  'ATL',
#  'MDW',
#  'DCA',
#  'MSY',
#  'JFK',
#  'JAX',
#  'JFK',
#  'DAL',
#  'BWI',
#  'RDU',
#  'MDW',
#  'IND',
#  'BWI',
#  'BOS',
#  'MSP',
#  'IAD',
#  'DEN',
#  'MCI',
#  'LAX',
#  'BNA',
#  'BWI',
#  'AUS',
#  'ATL',
#  'TUL',
#  'DAL',
#  'BDL',
#  'MCO',
#  'PHX',
#  'HOU',
#  'BWI',
#  'HOU',
#  'MSY',
#  'FLL',
#  'ELP',
#  'HOU',
#  'DEN',
#  'SMF',
#  'BNA',
#  'SAN',
#  'ISP',
#  'MCO',
#  'BNA',
#  'PHX',
#  'GRR',
#  'DTW',
#  'MKE',
#  'MSP',
#  'PVD',
#  'BWI',
#  'SAN',
#  'SLC',
#  'PDX',
#  'DEN',
#  'ROC',
#  'BWI',
#  'ELP',
#  'AUS',
#  'DAL',
#  'SAT',
#  'HOU',
#  'LAS',
#  'OMA',
#  'DEN',
#  'SDF',
#  'MCO',
#  'LGA',
#  'HOU',
#  'SJC',
#  'ATL',
#  'MDW',
#  'ATL',
#  'FLL',
#  'MDW',
#  'BNA',
#  'ATL',
#  'SFO',
#  'MSP',
#  'DEN',
#  'SJC',
#  'BWI',
#  'MDW',
#  'ATL',
#  'HOU',
#  'DCA',
#  'MCO',
#  'DCA',
#  'MDW',
#  'MSY',
#  'HOU',
#  'DAL',
#  'DCA',
#  'BWI',
#  'SAN',
#  'BNA',
#  'MDW',
#  'MCO',
#  'ATL',
#  'BWI',
#  'PHX',
#  'SAN',
#  'ATL',
#  'SAN',
#  'LAX',
#  'SAT',
#  'HOU',
#  'LAX',
#  'HOU',
#  'BUF',
#  'MCO',
#  'SAN',
#  'MSP',
#  'IND',
#  'FLL',
#  'JAX',
#  'ATL',
#  'MCO',
#  'DEN',
#  'ALB',
#  'MDW',
#  'GEG',
#  'BOI',
#  'MAF',
#  'DAL',
#  'MDW',
#  'TPA',
#  'SAN',
#  'DEN',
#  'ATL',
#  'PHX',
#  'SEA',
#  'SMF',
#  'SEA',
#  'ATL',
#  'PHX',
#  'MCI',
#  'CMH',
#  'BWI',
#  'MCI',
#  'LAX',
#  'CRP',
#  'HOU',
#  'MDW',
#  'OAK',
#  'DTW',
#  'BNA',
#  'GRR',
#  'DEN',
#  'PIT',
#  'BNA',
#  'AMA',
#  'DAL',
#  'MSN',
#  'MSP',
#  'SAN',
#  'MDW',
#  'ATL',
#  'BNA',
#  'LAX',
#  'MSP',
#  'BOI',
#  'LAS',
#  'MSP',
#  'ATL',
#  'BWI',
#  'ATL',
#  'SMF',
#  'SAN',
#  'GSP',
#  'ATL',
#  'LAS',
#  'MSP',
#  'RDU',
#  'BNA',
#  'MCO',
#  'BUF',
#  'STL',
#  'MCI',
#  'MSY',
#  'DAL',
#  'SMF',
#  'DEN',
#  'ICT',
#  'STL',
#  'JAX',
#  'BNA',
#  'BWI',
#  'MCO',
#  'OKC',
#  'DEN',
#  'TUL',
#  'STL',
#  'DSM',
#  'STL',
#  'RNO',
#  'DEN',
#  'LIT',
#  'STL',
#  'BOI',
#  'MSP',
#  'SLC',
#  'LAX',
#  'AUS',
#  'LAX',
#  'ORF',
#  'BWI',
#  'CLT',
#  'BNA',
#  'DAL',
#  'ATL',
#  'SAN',
#  'BWI',
#  'RSW',
#  'MDW',
#  'OAK',
#  'SAN',
#  'HOU',
#  'LGA',
#  'PVD',
#  'MCO',
#  'BWI',
#  'LAS',
#  'IND',
#  'DEN',
#  'RDU',
#  'LAX',
#  'MCI',
#  'BWI',
#  'LAS',
#  'HOU',
#  'FCA',
#  'MSP',
#  'ONT',
#  'DEN',
#  'LAX',
#  'MSY',
#  'LGA',
#  'ATL',
#  'STL',
#  'MDW',
#  'MSY',
#  'LAX',
#  'ONT',
#  'MDW',
#  'TPA',
#  'MSY',
#  'MCO',
#  'ISP',
#  'MSY',
#  'BWI',
#  'PHL',
#  'DEN',
#  'PDX',
#  'SMF',
#  'OAK',
#  'SLC',
#  'TPA',
#  'CMH',
#  'BNA',
#  'DEN',
#  'LAX',
#  'ATL',
#  'CVG',
#  'LAX',
#  'HOU',
#  'MCO',
#  'DEN',
#  'PHX',
#  'BUF',
#  'MDW',
#  'ORD',
#  'MSP',
#  'DAL',
#  'AUS',
#  'SMF',
#  'SNA',
#  'MSY',
#  'PHX',
#  'LAS',
#  'SJC',
#  'COS',
#  'ATL',
#  'LAX',
#  'BWI',
#  'SLC',
#  'ATL',
#  'SFO',
#  'MDW',
#  'BWI',
#  'DAL',
#  'SAN',
#  'PHX',
#  'DCA',
#  'FLL',
#  'OAK',
#  'MDW',
#  'HSV',
#  'ATL',
#  'MDW',
#  'LAX',
#  'DEN',
#  'OAK',
#  'MCI',
#  'STL',
#  'GSP',
#  'ATL',
#  'SAT',
#  'ATL',
#  'BOS',
#  'SEA',
#  'DEN',
#  'DTW',
#  'MCO',
#  'HOU',
#  'OAK',
#  'SNA',
#  'SJC',
#  'PHX',
#  'MDW',
#  'SAN',
#  'SJC',
#  'DEN',
#  'CMH',
#  'FLL',
#  'SMF',
#  'PHX',
#  'SFO',
#  'SEA',
#  'LAS',
#  'AUS',
#  'MCO',
#  'DAL',
#  'MSP',
#  'BWI',
#  'DEN',
#  'LAX',
#  'MCO',
#  'LGA',
#  'LIH',
#  'HNL',
#  'SMF',
#  'AUS',
#  'CLE',
#  'MDW',
#  'BNA',
#  'BOS',
#  'SAV',
#  'ATL',
#  'BNA',
#  'LAS',
#  'JFK',
#  'SLC',
#  'SEA',
#  'MDW',
#  'BZN',
#  'MSP',
#  'SNA',
#  'ATL',
#  'MSY',
#  'MDW',
#  'SNA',
#  'SMF',
#  'DEN',
#  'SEA',
#  'MDW',
#  'DEN',
#  'SMF',
#  'LAX',
#  'ATL',
#  'FLL',
#  'TUL',
#  'DEN',
#  'LBB',
#  'DEN',
#  'HOU',
#  'PHX',
#  'BOS',
#  'MCO',
#  'PHX',
#  'OAK',
#  'STL',
#  'BNA',
#  'TPA',
#  'FLL',
#  'AUS',
#  'DAL',
#  'ATL',
#  'TPA',
#  'SNA',
#  'LAS',
#  'MDW',
#  'BNA',
#  'SJC',
#  'DAL',
#  'MSY',
#  'ATL',
#  'MCO',
#  'BWI',
#  'GEG',
#  'DEN',
#  'PHX',
#  'SAN',
#  'LAX',
#  'DTW',
#  'LAS',
#  'SNA',
#  'SAN',
#  'AUS',
#  'CLT',
#  'MDW',
#  'LAX',
#  'SMF',
#  'ELP',
#  'DAL',
#  'ATL',
#  'LAX',
#  'HOU',
#  'BNA',
#  'PBI',
#  'ATL',
#  'MSP',
#  'TPA',
#  'PIT',
#  'TPA',
#  'MCI',
#  'ATL',
#  'STL',
#  'LAS',
#  'AUS',
#  'MCO',
#  'DEN',
#  'PDX',
#  'SMF',
#  'LAS',
#  'SJC',
#  'AUS',
#  'OMA',
#  'PHX',
#  'MSP',
#  'RSW',
#  'MSP',
#  'LAX',
#  'ALB',
#  'MCO',
#  'IND',
#  'RSW',
#  'MSP',
#  'LAS',
#  'BWI',
#  'TPA',
#  'DAL',
#  'MSY',
#  'ECP',
#  'BNA',
#  'BWI',
#  'CMH',
#  'CMH',
#  'LAS',
#  'SJU',
#  'BWI',
#  'BWI',
#  'MSY',
#  'MDW',
#  'DAL',
#  'LIT',
#  'DAL',
#  'ABQ',
#  'OAK',
#  'MDW',
#  'HOU',
#  'ATL',
#  'AUS',
#  'MCO',
#  'LAS',
#  'SAT',
#  'BNA',
#  'LAS',
#  'SLC',
#  'DEN',
#  'DAL',
#  'SJC',
#  'BUR',
#  'HOU',
#  'SAN',
#  'BOS',
#  'ATL',
#  'TUS',
#  'DEN',
#  'DCA',
#  'HOU',
#  'RDU',
#  'FLL',
#  'MCO',
#  'SEA',
#  'MSP',
#  'JFK',
#  'SNA',
#  'DEN',
#  'MSY',
#  'AUS',
#  'PBI',
#  'BWI',
#  'PHL',
#  'MCO',
#  'OKC',
#  'LAS',
#  'CMH',
#  'ATL',
#  'STL',
#  'DAL',
#  'SLC',
#  'LAS',
#  'DEN',
#  'MSP',
#  'ELP',
#  'LAS',
#  'PHX',
#  'DEN',
#  'PHX',
#  'BNA',
#  'CHS',
#  'BWI',
#  'DCA',
#  'TPA',
#  'HOU',
#  'DAL',
#  'MSY',
#  'TPA',
#  'CVG',
#  'BWI',
#  'MDW',
#  'BWI',
#  'LGA',
#  'FLL',
#  'PDX',
#  'JFK',
#  'RNO',
#  'LAS',
#  'CLE',
#  'ATL',
#  'ISP',
#  'PBI',
#  'MHT',
#  'TPA',
#  'LGB',
#  'SMF',
#  'LAX',
#  'OAK',
#  'KOA',
#  'HNL',
#  'CVG',
#  'ATL',
#  'SMF',
#  'PDX',
#  'MDW',
#  'CLE',
#  'MCO',
#  'MDW',
#  'MEM',
#  'ATL',
#  'DAL',
#  'ATL',
#  'OAK',
#  'PDX',
#  'DAL',
#  'HOU',
#  'SEA',
#  'SLC',
#  'HOU',
#  'MAF',
#  'SEA',
#  'SJC',
#  'SJC',
#  'LAS',
#  ...]

# %% [markdown]
# #### Device an algo to find all posible routes to take

# %%
all = list(set(routes)) # removes repeated values
len(all), len(routes)
# Out:
# (164, 6400180)

# %%
## Install additional libraries
# !pip install haversine
# !pip install airportsdata
# !pip install mealpy
# Out:
# Collecting haversine
#   Downloading haversine-2.8.1-py2.py3-none-any.whl (7.7 kB)
# Installing collected packages: haversine
# Successfully installed haversine-2.8.1
# Collecting airportsdata
#   Downloading airportsdata-20240415-py3-none-any.whl (911 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 911.0/911.0 kB 10.6 MB/s eta 0:00:00
# Installing collected packages: airportsdata
# Successfully installed airportsdata-20240415
# Collecting mealpy
#   Downloading mealpy-3.0.1-py3-none-any.whl (386 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 386.3/386.3 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.10/dist-packages (from mealpy) (1.25.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from mealpy) (3.7.1)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from mealpy) (1.11.4)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from mealpy) (2.0.3)
# Collecting opfunu>=1.0.0 (from mealpy)
#   Downloading opfunu-1.0.2-py3-none-any.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 73.8 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (24.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->mealpy) (2.8.2)
# Requirement already satisfied: requests>=2.27.0 in /usr/local/lib/python3.10/dist-packages (from opfunu>=1.0.0->mealpy) (2.31.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->mealpy) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->mealpy) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->mealpy) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.27.0->opfunu>=1.0.0->mealpy) (2024.2.2)
# Installing collected packages: opfunu, mealpy
# Successfully installed mealpy-3.0.1 opfunu-1.0.2

# %%
import airportsdata

def get_coordinates(geo_loc):
    airports = airportsdata.load('IATA')

    if geo_loc not in airports:
        return 0, 0
    return airports[geo_loc]['lat'], airports[geo_loc]['lon']

# %%
coor = [get_coordinates(x) for x in all]
waypoint = dict(zip(all, coor))

# %%
place = []
for key, val in waypoint.items():
    if (0,0) == val:
        place.append(key)
place
# Out:
# []

# %%
#waypoint['ISN'] = (48.1781, 103.6422) # Replaced the coordiantes with the real coordinates

# %% [markdown]
# <br><br><br>

# %% [markdown]
# #### Check the algo

# %%
import numpy as np
from mealpy import PermutationVar, Problem
from haversine import haversine, Unit
import math
import random

class RouteFinder(Problem):
    def __init__(self, bounds=None, minmax="min", data=None):
        self.data = data
        self.eps = 1e10  # Penalty function for vertex with 0 connection
        super().__init__(bounds, minmax)

    # Calculate the fitness of an individual
    def obj_func(self, x):
        x_decoded = self.decode_solution(x)
        individual = x_decoded["path"]

        total_distance = 0
        for idx in range(len(individual) - 1):
            start_node = individual[idx]
            end_node = individual[idx + 1]
            weight = self.data[start_node, end_node]
            if weight == 0:
                return self.eps
            total_distance += weight
        return total_distance

class Meta(RouteFinder):
    def __init__(self, waypoint, orig, dest, model_params):
        self.waypoint = waypoint
        self.graph = {}
        self.orig = orig
        self.dest = dest
        self.model = model_params['model']
        self.epoch = model_params['epoch']
        self.pop_size = model_params['pop_size']
        #self.dropout = (random.randrange(20, 80))/100
        self.dropout = 0.60 # test case

        self.path = [0, 0]
        self.orig_to_dest = [0, 0]
        self.graph_mat = []
        self.num_vertices = len(self.graph_mat)
        self.check_dist = 0

        '''
        model_params = {model, epoch, population size}

        model - has to be a mealpy class (eg. ACOR, WOA, GA...)
        epoch - must be int type only
        population size - must also be int type
        '''

    ## Creates model
    def __create_model(self, graph):
        num_nodes = len(graph)
        bounds = PermutationVar(valid_set=list(range(0, num_nodes)), name="path")
        problem = RouteFinder(bounds=bounds, minmax="min", data=graph)
        model = self.model(self.epoch, self.pop_size)
        model.solve(problem)

        return model

    ## Validates traversal order (medyo weird naman kung nauna dest sa orgin)
    def __validate_order(self, model):
        check_model_dist = model.problem.decode_solution(model.g_best.solution)['path']
        return check_model_dist.index(self.orig_to_dest[0]) > check_model_dist.index(self.orig_to_dest[1])

    def __update_graph(self, new_graph):
        self.graph = new_graph

    def __update_graph_mat(self, new_mat):
        self.graph_mat = new_mat

    ## Generates graph from coordinates
    def __generate_graph(self, waypoint):
        graph = {}

        for city1, coords1 in waypoint.items():
            graph[city1] = {}
            for city2, coords2 in waypoint.items():
                if city1 != city2:
                    distance = haversine(coords1, coords2, unit=Unit.KILOMETERS)
                    graph[city1][city2] = round(distance, 2)

        self.graph = graph

    def __remove_edge(self, node1, node2):
        if node1 in self.graph and node2 in self.graph[node1]:
            del self.graph[node1][node2]
        if node2 in self.graph and node1 in self.graph[node2]:
            del self.graph[node2][node1]

    ## Creates a matrix from graph
    def __create_graph_matrix(self, graph):
        nodes = sorted(graph.keys())
        #node_to_idx = {node: i for i, node in enumerate(nodes)} # Find idx of each key, run in case na malito

        nodes = sorted(list(graph.keys()))
        num_nodes = len(nodes)
        graph_matrix = np.zeros((num_nodes, num_nodes))

        for i, node1 in enumerate(nodes):
            for j, node2 in enumerate(nodes):
                if node2 in graph[node1]:
                    graph_matrix[i][j] = graph[node1][node2]

        return graph_matrix

    ## Maps the index to the graph, traversing through the node
    def __map_result_to_graph(self, result):
        mapped_result = []
        for node_index in result:
            node_name = list(sorted(self.graph.keys()))[node_index]
            mapped_result.append(node_name)
        return mapped_result # returns list of char

    ## Calculates the distance from start node to end node
    def __calculate_distance(self, graph, nodes):
        total_distance = 0
        for i in range(len(nodes) - 1):
            current_node = nodes[i]
            next_node = nodes[i + 1]
            if current_node in graph and next_node in graph[current_node]:
                total_distance += graph[current_node][next_node]
            else:
                print(f"No direct connection between {current_node} and {next_node}.")
                total_distance += np.inf  # In case no edge, add infinity instead because... Why not?
        return total_distance # returns float

    ## Creates a new graph from the previous graph
    def __create_subgraph(self, graph, nodes_to_go_through):
        subgraph = {}
        for node in nodes_to_go_through:
            if node in graph:
                subgraph[node] = {}
                for neighbor, distance in graph[node].items():
                    if neighbor in nodes_to_go_through:
                        subgraph[node][neighbor] = distance

        # Remove edges between the first and last nodes
        if nodes_to_go_through[0] in subgraph and nodes_to_go_through[-1] in subgraph[nodes_to_go_through[0]]:
            del subgraph[nodes_to_go_through[0]][nodes_to_go_through[-1]]
        if nodes_to_go_through[-1] in subgraph and nodes_to_go_through[0] in subgraph[nodes_to_go_through[-1]]:
            del subgraph[nodes_to_go_through[-1]][nodes_to_go_through[0]]

        return subgraph

    ## Updates nodes
    def __update_start_end(self, new_start, new_end):
        self.orig_to_dest[0] = (new_start)
        self.orig_to_dest[1] = (new_end)

    ## Update params of the model
    def __update_params(self):
        if self.epoch > 5 and self.pop_size > 5:
            self.epoch = self.epoch - math.ceil(self.epoch*self.dropout)
            #self.pop_size = self.pop_size - math.ceil(self.pop_size*self.dropout)
        else:
          pass

    ## Update node idx
    def __update_node_idx(self):
        nodes = sorted(self.graph.keys())
        node_idx = {node: i for i, node in enumerate(nodes)}

        self.path[0] = node_idx[self.orig]
        self.path[1] = node_idx[self.dest]

    ## Distance checking with dijkstra
    def __dijkstra(self, graph, start, end):
        num_vertices = len(graph)
        shortest_distances = [float('inf')] * num_vertices
        shortest_distances[start] = 0
        visited = [False] * num_vertices
        path = [-1] * num_vertices

        for _ in range(num_vertices):
            min_distance = float('inf')
            min_index = -1
            for v in range(num_vertices):
                if not visited[v] and shortest_distances[v] < min_distance:
                    min_distance = shortest_distances[v]
                    min_index = v
            visited[min_index] = True
            for v in range(num_vertices):
                if not visited[v] and graph[min_index][v] != 0 and shortest_distances[min_index] + graph[min_index][v] < shortest_distances[v]:
                    shortest_distances[v] = shortest_distances[min_index] + graph[min_index][v]
                    path[v] = min_index

        shortest_path = []
        current = end
        while current != -1:
            shortest_path.append(current)
            current = path[current]
        shortest_path.reverse()

        return shortest_distances[end]


    ## Runs the code
    def run_meta(self):

        ## Initialize starting parameters
        self.__generate_graph(self.waypoint) ## Generate graph
        self.__remove_edge(self.orig, self.dest)

        mat = self.__create_graph_matrix(self.graph)
        self.__update_graph_mat(mat) # Updates graph into matrix
        self.__update_node_idx()
        self.__update_start_end(self.path[0], self.path[1])
        self.check_dist = self.__dijkstra(self.graph_mat, self.path[0], self.path[1])

        for _ in range(120):
            while True:
                model = self.__create_model(self.graph_mat)
                if not self.__validate_order(model):
                    break

            path = model.problem.decode_solution(model.g_best.solution)['path']
            path = path[path.index(self.orig_to_dest[0]):path.index(self.orig_to_dest[1])+1] # Takes the orig to dest route


            map_result = self.__map_result_to_graph(path)
            distance = self.__calculate_distance(self.graph, map_result) # Gets distance because... Why not?

            sub_graph = self.__create_subgraph(self.graph, map_result) # New graph created
            self.__update_graph(sub_graph)

            self.__update_node_idx()

            self.__update_start_end(self.path[0], self.path[1]) # update origin and dest
            self.__update_graph_mat(self.__create_graph_matrix(self.graph))
            self.__update_params()

            if distance <= self.check_dist:
              break

        return map_result, distance, self.check_dist

# %%
orig, dest = 'ORD', 'DEN'

# %% [markdown]
# <br><br><br>

# %% [markdown]
# #### Final Testing

# %%
from mealpy import ACOR, GA, PSO, BeesA, SA
import time

# %%
## test for n times
run = 10

ant = ACOR.OriginalACOR
genetic = GA.BaseGA
particle = PSO.OriginalPSO
#sim = SA.OriginalSA
#bee = BeesA.OriginalBeesA

model_list = [ant, genetic, particle]
final_test = [[[] for _ in range(len(model_list))] for _ in range(run)]

model_name = ['ant', 'genetic', 'particle']

for i in range(run):
    for j in range(len(model_list)):
        params = {
          'model': model_list[j],
          'epoch': 100,
          'pop_size': 20
          }

        router = Meta(waypoint, orig, dest, params)
        start_time = time.time()

        res = router.run_meta()

        end_time = time.time()

        elapsed_time = end_time - start_time

        final_test[i][j] = (model_name[j], res, elapsed_time)
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:mealpy.swarm_based.ACOR.OriginalACOR:>>>Problem: P, Epoch:
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 8920.18, Global best: 8605.36, Runtime: 0.00510 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 10535.58, Global best: 8605.36, Runtime: 0.00552 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 3, Current best: 9573.18, Global best: 8605.36, Runtime: 0.01054 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 4, Current best: 8623.539999999999, Global best: 8605.36, Runtime: 0.00875 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 5, Current best: 8564.489999999998, Global best: 8564.489999999998, Runtime: 0.00563 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 6, Current best: 5949.17, Global best: 5949.17, Runtime: 0.00500 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 7, Current best: 8213.28, Global best: 5949.17, Runtime: 0.00630 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 8, Current best: 6782.49, Global best: 5949.17, Runtime: 0.00494 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 9, Current best: 5949.17, Global best: 5949.17, Runtime: 0.00648 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 10, Current best: 7655.23, Global best: 5949.17, Runtime: 0.00460 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 11, Current best: 5949.17, Global best: 5949.17, Runtime: 0.00533 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 12, Current best: 5949.17, Global best: 5949.17, Runtime: 0.00598 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 13, Current best: 7742.4400000000005, Global best: 5949.17, Runtime: 0.00521 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 14, Current best: 8213.28, Global best: 5949.17, Runtime: 0.00574 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 15, Current best: 7472.629999999999, Global best: 5949.17, Runtime: 0.00659 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 16, Current best: 8213.28, Global best: 5949.17, Runtime: 0.00500 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00627 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00491 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 3, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00556 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 4, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00586 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 5, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00479 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 6, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00561 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00576 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00430 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00451 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00643 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00650 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00571 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00570 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00446 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00438 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00478 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00547 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00696 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00579 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00582 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00791 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00493 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00472 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00762 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00658 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00490 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00523 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00574 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00672 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00758 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00731 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00694 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00811 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00898 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00540 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00541 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00940 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00827 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00533 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00532 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00534 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00594 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00796 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00867 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00539 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00794 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00435 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00900 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00480 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00481 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00790 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00827 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00733 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00503 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00476 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00493 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00518 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00525 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00521 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00561 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00464 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00532 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00560 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 2, Current best: 1991.0, Global best: 1991.0, Runtime: 0.00531 seconds
# INFO:mealpy.evolutionary_based.GA.BaseGA:Solving single objective optimization problem.
# INFO:mealpy.evolutionary_based.GA.BaseGA:>>>Problem: P, Epoch: 1, Current best: 1991.0, Global best: 1991.0, Runtime: 0.
#   ('particle', (['ORD', 'ROC', 'DEN'], 3115.41, 1425.75), 12.392560005187988)],
#  [('ant',
#    (['ORD', 'FSD', 'RAP', 'DEN'], 1735.52, 1425.75),
#    151.72226428985596),
#   ('genetic',
#    (['ORD', 'STL', 'DEN'], 1650.6399999999999, 1425.75),
#    11.080620765686035),
#   ('particle', (['ORD', 'CAK', 'DEN'], 2516.55, 1425.75), 13.301478385925293)],
#  [('ant', (['ORD', 'MAF', 'DEN'], 2594.49, 1425.75), 88.40255117416382),
#   ('genetic', (['ORD', 'CVG', 'DEN'], 2141.79, 1425.75), 19.85079002380371),
#   ('particle', (['ORD', 'FNT', 'DEN'], 2141.33, 1425.75), 16.486574172973633)],
#  [('ant',
#    (['ORD', 'JAX', 'DAB', 'SRQ', 'DEN'], 4259.1, 1425.75),
#    186.43185305595398),
#   ('genetic', (['ORD', 'GRB', 'DEN'], 1733.23, 1425.75), 12.816239356994629),
#   ('particle', (['ORD', 'GPT', 'DEN'], 3052.17, 1425.75), 11.08570122718811)],
#  [('ant',
#    (['ORD', 'FAR', 'DEN'], 1903.1599999999999, 1425.75),
#    177.3164484500885),
#   ('genetic', (['ORD', 'MSN', 'DEN'], 1500.4, 1425.75), 13.275537014007568),
#   ('particle',
#    (['ORD', 'RAP', 'BIL', 'DEN'], 2457.73, 1425.75),
#    15.286033391952515)],
#  [('ant', (['ORD', 'RIC', 'DEN'], 3411.16, 1425.75), 110.9094066619873),
#   ('genetic', (['ORD', 'AMA', 'DEN'], 1991.0, 1425.75), 11.670381307601929),
#   ('particle', (['ORD', 'MKE', 'DEN'], 1545.8, 1425.75), 15.935098886489868)],
#  [('ant', (['ORD', 'FSD', 'DEN'], 1519.24, 1425.75), 102.6085889339447),
#   ('genetic',
#    (['ORD', 'PHF', 'GSO', 'DEN'], 3644.35, 1425.75),
#    19.4722158908844),
#   ('particle', (['ORD', 'FNT', 'DEN'], 2141.33, 1425.75), 11.727788209915161)]]

# %% [markdown]
# #### Find the algo with lowest distance

# %%
temp, algo = [[0 for _ in range(len(model_list))] for _ in range(run)], [['' for _ in range(len(model_list))] for _ in range(run)]
for i in range(run):
    for j in range(len(model_list)):
        temp[i][j] = final_test[i][j][1][1]
        algo[i][j] = final_test[i][j][0]

combined_sets = []
for algo_list, temp_list in zip(algo, temp):
    combined_set = {(x, y) for x, y in zip(algo_list, temp_list)}
    combined_sets.append(combined_set)

combined_sets
# Out:
# [{('ant', 2746.0), ('genetic', 2332.34), ('particle', 2358.38)},
#  {('ant', 1650.6399999999999), ('genetic', 1580.02), ('particle', 1910.22)},
#  {('ant', 1776.7199999999998),
#   ('genetic', 1903.1599999999999),
#   ('particle', 1425.75)},
#  {('ant', 4331.030000000001), ('genetic', 1426.54), ('particle', 3115.41)},
#  {('ant', 1735.52), ('genetic', 1650.6399999999999), ('particle', 2516.55)},
#  {('ant', 2594.49), ('genetic', 2141.79), ('particle', 2141.33)},
#  {('ant', 4259.1), ('genetic', 1733.23), ('particle', 3052.17)},
#  {('ant', 1903.1599999999999), ('genetic', 1500.4), ('particle', 2457.73)},
#  {('ant', 3411.16), ('genetic', 1991.0), ('particle', 1545.8)},
#  {('ant', 1519.24), ('genetic', 3644.35), ('particle', 2141.33)}]

# %%
min_values = []
min_strings = []
for combined_set in combined_sets:
    min_value = float('inf')
    min_string = ''
    for string, value in combined_set:
        if value != float('inf') and value < min_value:
            min_value = value
            min_string = string
    min_values.append(min_value)
    min_strings.append(min_string)

print("Best Score:", min_values)
print("By Algo:", min_strings)
# Out:
# Best Score: [2332.34, 1580.02, 1425.75, 1426.54, 1650.6399999999999, 2141.33, 1733.23, 1500.4, 1545.8, 1519.24]
# By Algo: ['genetic', 'genetic', 'particle', 'genetic', 'genetic', 'particle', 'genetic', 'genetic', 'particle', 'ant']

# %%
resulting_factor = [{x, y} for x, y in zip(min_strings, min_values)]
resulting_factor
# Out:
# [{2332.34, 'genetic'},
#  {1580.02, 'genetic'},
#  {1425.75, 'particle'},
#  {1426.54, 'genetic'},
#  {1650.6399999999999, 'genetic'},
#  {2141.33, 'particle'},
#  {1733.23, 'genetic'},
#  {1500.4, 'genetic'},
#  {1545.8, 'particle'},
#  {1519.24, 'ant'}]

# %% [markdown]
# #### Lowest distance

# %%
from collections import Counter

# Count occurrences of each element in the list
counts = Counter(min_strings)

# Find the most common value and its count
most_common_value = counts.most_common(1)[0][0]
count_of_most_common_value = counts[most_common_value]

print("Best algo:", most_common_value)
print("Occurences:", count_of_most_common_value)
# Out:
# Best algo: genetic
# Occurences: 6

# %%
from collections import Counter

counts = Counter(min_strings)

sorted_counts = sorted(counts.items(), key=lambda x: x[1], reverse=True)
ranked_values = {value: rank + 1 for rank, (value, count) in enumerate(sorted_counts) if count > 1}

print("Repeated values ranked by frequency:")
for value, rank in ranked_values.items():
    print(f"Value: {value}, Rank: {rank}")
# Out:
# Repeated values ranked by frequency:
# Value: genetic, Rank: 1
# Value: particle, Rank: 2

# %% [markdown]
# #### Results

# %%
final_test[0][1][1][:]
# Out:
# (['ORD', 'DAL', 'DEN'], 2332.34, 1425.75)

# %% [markdown]
# **Metaheuristic Algorithms: Ant, Genetic, Particle**

# %%
## TIME & DISTANCE
idx = 0

while idx <= 2:
    average_time, average_dist = [], []
    for i in range(run):
        average_dist.append(final_test[i][idx][1][1])

    for i in range(run):
        average_time.append(final_test[i][idx][2])

    print(f'{model_name[idx]} | Average Exec. time: {(sum(average_time)/run):.2f}, Average Distance: {(sum(average_dist)/run):.2f}')
    idx+=1
    if idx > 2:
        break
# Out:
# ant | Average Exec. time: 150.78, Average Distance: 2592.71
# genetic | Average Exec. time: 14.73, Average Distance: 1990.35
# particle | Average Exec. time: 13.63, Average Distance: 2266.47

# %% [markdown]
# | Algorithm | Execution Time (s) | Distance (km)|
# | :-- | :-: | :-: |
# | Ant Colony Optimization | 150.78 | 2592.71 |
# | Genetic Algorithm | 14.73 | 1990.35 |
# | Particle Swarm Optimization | 13.63 | 2266.47 |
#
# The table above shows the average values made by the algorithm, they were chosen based on the minimum values they gave; this test was repeated 10 times (Error fixed: The first table was a mistake because index was not moving)
